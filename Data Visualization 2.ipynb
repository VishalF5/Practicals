# %%
import numpy as np
import seaborn as sea
import pandas as pd
import os
import matplotlib.pyplot as plt

os.chdir("C:\\Users\\F5\\Documents\\Part 1\\FDS\\Prac\\Data Visualization")
cars_data=pd.read_csv('Toyota.csv',index_col=0,na_values=["??","????"])
cars_data.size
# Out:
# 14360

# %%
cars_data.dropna(axis=0,inplace=True)
cars_data.size
# Out:
# 10960

# %%
sea.regplot(x=cars_data['Age'],y=cars_data['Price'])
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Price'>

# %%
sea.regplot(x=cars_data['Age'],y=cars_data['Price'],fit_reg=False)
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Price'>

# %%
sea.regplot(x=cars_data['Age'],y=cars_data['Price'],marker='+')
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Price'>

# %%
sea.lmplot(x='Age',y='Price',data=cars_data,hue='FuelType',fit_reg=False,legend=True,palette='Set1')

# %%
sea.histplot(cars_data['Age'],kde=True)
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Count'>

# %%
sea.histplot(cars_data['Age'])
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Count'>

# %%
sea.histplot(cars_data['Age'],bins=5)
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Count'>

# %%
sea.countplot(x=cars_data['FuelType'])
# Out:
# <AxesSubplot:xlabel='FuelType', ylabel='count'>

# %%
sea.countplot(x=cars_data['FuelType'],hue=cars_data['Automatic'])
# Out:
# <AxesSubplot:xlabel='FuelType', ylabel='count'>

# %%
pd.crosstab(index=cars_data["Automatic"],columns=cars_data['FuelType'],dropna=True)
# Out:
# FuelType   CNG  Diesel  Petrol
# Automatic
# 0           12     116     910
# 1            0       0      58

# %%
sea.boxplot(x=cars_data['FuelType'],y=cars_data['Price'])
# Out:
# <AxesSubplot:xlabel='FuelType', ylabel='Price'>

# %%
sea.boxplot(x=cars_data['FuelType'],y=cars_data['Price'],hue=cars_data['Automatic'])
# Out:
# <AxesSubplot:xlabel='FuelType', ylabel='Price'>

# %%
f,(ax_box,ax_hist)=plt.subplots(2,gridspec_kw={'height_ratios':(.15,.85)})
sea.boxplot(cars_data['Price'],ax=ax_box)
sea.histplot(cars_data['Price'],ax=ax_hist,kde=False)
# Out:
# C:\Users\F5\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Price', ylabel='Count'>

# %%
sea.pairplot(cars_data,kind='scatter',hue='FuelType',diag_kws={'bw':0.1})
# Out:
# C:\Users\F5\anaconda3\lib\site-packages\seaborn\distributions.py:1657: FutureWarning: The `bw` parameter is deprecated in favor of `bw_method` and `bw_adjust`. Using 0.1 for `bw_method`, but please see the docs for the new parameters and update your code.
#   warnings.warn(msg, FutureWarning)
# C:\Users\F5\anaconda3\lib\site-packages\seaborn\distributions.py:1657: FutureWarning: The `bw` parameter is deprecated in favor of `bw_method` and `bw_adjust`. Using 0.1 for `bw_method`, but please see the docs for the new parameters and update your code.
#   warnings.warn(msg, FutureWarning)
# C:\Users\F5\anaconda3\lib\site-packages\seaborn\distributions.py:1657: FutureWarning: The `bw` parameter is deprecated in favor of `bw_method` and `bw_adjust`. Using 0.1 for `bw_method`, but please see the docs for the new parameters and update your code.
#   warnings.warn(msg, FutureWarning)
# ...

# %%
data=np.random.randint(1,100,size=(10,10))
print(data)
# Out:
# [[ 5 81 87 76 29 30 56 33 27 68]
#  [56 34 89 22  2  8 73 53 14 29]
#  [72 15 27 71 12 83 37 35 90 29]
#  [75 88  2 98 39 98 85 73  4 40]
#  [10 79 75  3  1 72 83 20 19 24]
#  [71 13 32  8 10 49 72 23 16 87]
#  [56 50 29 50 65 52 41 90 37 82]
#  [10  9 61 80 25 28 74 43 81 67]
#  [23 66 50 70 83 98 76 87 81 48]
#  [56 56 23 65 35 40 50 72 33 76]]

# %%
hm=sea.heatmap(data=data)
plt.show()

# %%
hm=sea.heatmap(data=data,vmin='30',vmax='70')
plt.show()

# %%
cmap='tab20'
center=0
annot=True
h=sea.heatmap(data=data,annot=annot,cmap=cmap)
plt.show()
